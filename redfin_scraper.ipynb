# %%
import os
import urllib
from datetime import datetime
import requests
import time
import wget
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d86ed72cbdaa> in <module>
#       4 import requests
#       5 import time
# ----> 6 import wget
#
# ModuleNotFoundError: No module named 'wget'

# %%
# params
max_price = 900000
date_time = datetime.now().strftime("%m%d%Y")
download_folder = "/Users/szhang/Downloads/"

# base url
base_url = 'https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id={region_id}&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8'

# fake headers
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

# %%
elementary_schools = {
    "Mosby Woods Elementary": 55716,
    "Navy Elementary School": 54146,
    "Poplar Tree Elementary": 53030,
    "Colvin Run Elementary": 51493,
    "Spring Hill Elementary": 104262,
    "Oakton Elementary": 98453,
    "Mill Run Elementary": 123504,
    "Madison's Trust Elementary": 231881,
    "Westbriar Elementary": 56040,
    "Wolftrap Elementary": 129050
}

middle_schools = {
    "Cooper Middle School": 142292, # 好
#     "Frost Middle School": 122278, # 好
    "Longfellow Middle School": 55897,
    "Carson Middle School": 90165,
    "Eagle Ridge Middle School": 116345,
    "Rocky Run Middle": 159468,
    "Franklin Middle School": 53305
}

high_schools = {
    "McLean High School": 116658,
    "Langley High School": 141517,
    "Oakton High School": 121474,
    "Briar Woods High School": 122224,
    "Chantilly High School": 139177
}

# %%
def _create_folder(folder: str, file_name: str):
    path = os.path.join(folder, file_name)
    if not os.path.exists(path):
        os.mkdir(path)
    print(path)
    
# create today's folder
print("creating date folder..")
_create_folder(download_folder, date_time)
today_path = download_folder + date_time


# create elementary_school's folder
print("creating elementary_school folder..")
elementary_school = "elementary_schools"
_create_folder(today_path, elementary_school)
e_school_path = today_path + "/" + elementary_school

# create middle school's folder
print("creating middle_school folder..")
middle_school = "middle_schools"
_create_folder(today_path, middle_school)
m_school_path = today_path + "/" + middle_school


# TODO: create high school's folder
print("creating high_school folder..")
high_school = "high_schools"
_create_folder(today_path, high_school)
h_school_path = today_path + "/" + high_school
# Out:
# creating date folder..
# /Users/szhang/Downloads/01152022
# creating elementary_school folder..
# /Users/szhang/Downloads/01152022/elementary_schools
# creating middle_school folder..
# /Users/szhang/Downloads/01152022/middle_schools
# creating high_school folder..
# /Users/szhang/Downloads/01152022/high_schools

# %%
def _generate_url(base_url: str, region_id: str):
    updated_url = base_url.format(region_id=region_id)
    updated_url += "&max_price=" + str(max_price)
    return updated_url

def _download_csv(url: str, path: str, school_name: str):
    file_name = school + '.csv'
    if not os.path.exists(path + "/" + school + '.csv'):
        response = requests.get(url, headers=headers)
        with open(os.path.join(path, school + '.csv'), 'wb') as f:
            f.write(response.content)
    else:
        print("File of school zone: " + school + "is exist.")
        
# download elementaryschools houses
for school in elementary_schools:
    time.sleep(2)
    url = _generate_url(base_url, elementary_schools[school])
    print(url)
    _download_csv(url, e_school_path, school)

    
# download middle schools houses
for school in middle_schools:
    time.sleep(2)
    url = _generate_url(base_url, middle_schools[school])
    print(url)
    _download_csv(url, m_school_path, school)
    
# TODO: download high schools houses
for school in high_schools:
    time.sleep(2)
    url = _generate_url(base_url, high_schools[school])
    print(url)
    _download_csv(url, h_school_path, school)
# Out:
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=123504&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=98453&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=231881&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=53030&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=51493&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=55716&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=56040&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=54146&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=129050&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=104262&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=142292&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=116345&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=90165&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=159468&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=53305&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=55897&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=116658&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=122224&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=141517&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=139177&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000
# https://www.redfin.com/stingray/api/gis-csv?al=1&isRentals=false&market=dc&num_homes=350&ord=redfin-recommended-asc&page_number=1&region_id=121474&region_type=7&sf=1,2,3,5,6,7&status=9&uipt=1,2,3,4,5,6,7,8&v=8&max_price=900000

# %%
import pandas as pd
import glob

# %%
# elementary_schools DF
e_joined_files = os.path.join(e_school_path, "*.csv")
e_joined_list = glob.glob(e_joined_files)
# print(e_joined_list)

e_dataframes = []

for file in e_joined_list:
    df = pd.read_csv(file)
    schools_info = file.split("/")
    df['Elementary School'] = file.split("/")[-1].replace(".csv", "")
    e_dataframes.append(df)
    
e_df = pd.concat(e_dataframes)
e_df['MLS Number'] = e_df['MLS#']
e_df = e_df.set_index('MLS#')
# e_df

# %%
# middle schools DF
m_joined_files = os.path.join(m_school_path, "*.csv")
m_joined_list = glob.glob(m_joined_files)
# print(m_joined_list)

m_dataframes = []

for file in m_joined_list:
    df = pd.read_csv(file)
    schools_info = file.split("/")
    df['Middle School'] = file.split("/")[-1].replace(".csv", "")
    m_dataframes.append(df)
    
m_df = pd.concat(m_dataframes)
m_df['MLS Number'] = m_df['MLS#']
m_df = m_df.set_index('MLS#')
# m_df

# %%
# high schools DF
h_joined_files = os.path.join(h_school_path, "*.csv")
h_joined_list = glob.glob(h_joined_files)
# print(h_joined_list)

h_dataframes = []

for file in h_joined_list:
    df = pd.read_csv(file)
    schools_info = file.split("/")
    df['High School'] = file.split("/")[-1].replace(".csv", "")
    h_dataframes.append(df)
    
h_df = pd.concat(h_dataframes)
h_df['MLS Number'] = h_df['MLS#']
h_df = h_df.set_index('MLS#')
# h_df

# %%
# merge dataframes
merged_df = e_df.merge(m_df, how='outer').merge(h_df, how='outer')

# clean up dataframes
result = merged_df.drop(columns=['SOLD DATE', 'STATE OR PROVINCE', 'LOCATION', 'NEXT OPEN HOUSE START TIME', 'NEXT OPEN HOUSE END TIME', 'SOURCE', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'])
result
# Out:
#                  SALE TYPE              PROPERTY TYPE  \
# 0              MLS Listing                Condo/Co-op
# 1              MLS Listing                Condo/Co-op
# 2              MLS Listing                Condo/Co-op
# 3              MLS Listing                Condo/Co-op
# 4              MLS Listing                Condo/Co-op
# 5    New Construction Home                Condo/Co-op
# 6    New Construction Home                Condo/Co-op
# 7    New Construction Plan                Condo/Co-op
# 8    New Construction Plan                Condo/Co-op
# 9    New Construction Plan                Condo/Co-op
# 10   New Construction Plan                Condo/Co-op
# 11   New Construction Plan                Condo/Co-op
# 12   New Construction Plan                  Townhouse
# 13             MLS Listing  Single Family Residential
# 14             MLS Listing  Single Family Residential
# 15             MLS Listing  Single Family Residential
# 16             MLS Listing  Single Family Residential
# 17             MLS Listing  Single Family Residential
# 18             MLS Listing                  Townhouse
# 19             MLS Listing                Condo/Co-op
# 20             MLS Listing                Condo/Co-op
# 21             MLS Listing                Condo/Co-op
# 21    1.0    1.0        762.0       NaN      1988.0            36.0
# 22    1.0    1.5       1061.0       NaN      2008.0           171.0
# 23    2.0    2.0       1132.0       NaN      1978.0             1.0
# 24    2.0    1.5       1077.0       NaN      1980.0            18.0
# 25    1.0    1.0        689.0       NaN      1988.0            46.0
# 26    2.0    2.0       1504.0       NaN      1978.0            47.0
# 27    1.0    1.0        762.0       NaN      1988.0            57.0
# 28    1.0    1.0        624.0       NaN      1988.0            59.0
# 29    3.0    2.0       1504.0       NaN      1980.0            73.0
# ..    ...    ...          ...       ...         ...             ...
# 114   2.0    2.0       1031.0       NaN      2005.0           111.0
# 115   3.0    4.0       1940.0     704.0      2021.0           113.0
# 116   3.0    2.5       2022.0     880.0      2021.0           113.0
# 117   4.0    4.0       2490.0     871.0         NaN           115.0
# 118   2.0    2.0       1515.0       NaN      2021.0           214.0
# 119   3.0    2.5       2719.0    1152.0      2021.0           352.0
# 120   3.0    2.5       2497.0    1152.0      2021.0           352.0
# 121   3.0    2.5       2446.0       NaN         NaN             NaN
# 122   4.0    3.5       2377.0       NaN         NaN             NaN
# 123   3.0    4.0       1940.0       NaN         NaN             NaN
# 124   5.0    4.0       2736.0       NaN         NaN             NaN
# 125   4.0    3.5       2022.0       NaN         NaN             NaN
# 126   5.0    4.0       2506.0       NaN         NaN             NaN
# 127   3.0    3.0       1548.0       NaN         NaN             NaN
# 128   3.0    2.5       2481.0       NaN         NaN             NaN
# 129   2.0    2.0       1495.0       NaN         NaN             NaN
# 130   2.0    2.0       1658.0       NaN         NaN             NaN
# 131   2.0    2.0       1469.0       NaN         NaN             NaN
# 132   2.0    2.0       1515.0       NaN         NaN             NaN
# 133   2.0    2.0       1451.0       NaN         NaN             NaN
# 134   2.0    2.0       1275.0       NaN         NaN             NaN
# 135   2.0    2.0       1506.0       NaN      2014.0             4.0
# 136   2.0    2.0       1330.0       NaN      2020.0            11.0
# 137   2.0    2.0       1391.0       NaN      2021.0            58.0
# 138   2.0    2.0       1391.0       NaN      2021.0            86.0
# 139   2.0    2.0       1391.0       NaN      2021.0           173.0
# 140   2.0    2.0       1532.0       NaN      2021.0           173.0
# 141   2.0    2.0       1391.0       NaN      2021.0           185.0
# 142   2.0    2.0       1532.0       NaN         NaN             NaN
# 143   2.0    2.0       1391.0       NaN         NaN             NaN
#
#      $/SQUARE FEET  HOA/MONTH  STATUS  \
# 0            366.0      390.0  Active
# 1            357.0      390.0  Active
# 2            387.0      390.0  Active
# 3            384.0      390.0  Active
# 4            386.0      390.0  Active
# 5            395.0        NaN  Active
# 6            272.0        NaN  Active
# 7            366.0        NaN  Active
# 8            357.0        NaN  Active
# 9            387.0        NaN  Active
# 10           386.0        NaN  Active
# 11           384.0        NaN  Active
# 12           384.0        NaN  Active
# 13           566.0        NaN  Active
# 14           376.0       13.0  Active
# 15           301.0       43.0  Active
# 16           322.0      206.0  Active
# 17           378.0        NaN  Active
# 18           442.0      110.0  Active
# 19           264.0      525.0  Active
# 26       Spring Hill Elementary     VAFX2032500  Longfellow Middle School
# 27       Spring Hill Elementary     VAFX2031402  Longfellow Middle School
# 28       Spring Hill Elementary     VAFX2030436  Longfellow Middle School
# 29       Spring Hill Elementary     VAFX2028792  Longfellow Middle School
# ..                          ...             ...                       ...
# 114                         NaN     VAFX2024248      Carson Middle School
# 115                         NaN     VAFX2024390      Carson Middle School
# 116                         NaN     VAFX2024386      Carson Middle School
# 117                         NaN     VAFX2023880      Carson Middle School
# 118                         NaN     VAFX2000686      Carson Middle School
# 119                         NaN     VAFX1178186      Carson Middle School
# 120                         NaN     VAFX1177994      Carson Middle School
# 121                         NaN  Plan-181720282      Carson Middle School
# 122                         NaN  Plan-181939532      Carson Middle School
# 123                         NaN  Plan-181885689      Carson Middle School
# 124                         NaN  Plan-181910609      Carson Middle School
# 125                         NaN  Plan-181885688      Carson Middle School
# 126                         NaN  Plan-181910608      Carson Middle School
# 127                         NaN  Plan-181885687      Carson Middle School
# 128                         NaN  Plan-181916749      Carson Middle School
# 129                         NaN  Plan-171734102      Carson Middle School
# 130                         NaN  Plan-171734103      Carson Middle School
# 131                         NaN  Plan-171734101      Carson Middle School
# 132                         NaN  Plan-171734100      Carson Middle School
# 133                         NaN  Plan-171734099      Carson Middle School
# 134                         NaN  Plan-171734098      Carson Middle School
# 135                         NaN     VAFX2040970                       NaN
# 136                         NaN     VAFX2038710                       NaN
# 137                         NaN     VAFX2031502                       NaN
# 138                         NaN     VAFX2027382                       NaN
# 139                         NaN         2058771                       NaN
# 140                         NaN         2058774                       NaN
# 141                         NaN         2054270                       NaN
# 142                         NaN  Plan-181762835                       NaN
# 143                         NaN  Plan-181762833                       NaN
#
#                High School
# 0       Oakton High School
# 1       Oakton High School
# 2       Oakton High School
# 3       Oakton High School
# 4       Oakton High School
# 5       Oakton High School
# 6       Oakton High School
# 7       Oakton High School
# 8       Oakton High School
# 9       Oakton High School
# 10      Oakton High School
# 11      Oakton High School
# 12      Oakton High School
# 13                     NaN
# 14   Chantilly High School
# 15   Chantilly High School
# 16                     NaN
# 17      Oakton High School
# 18      Oakton High School
# 19      Oakton High School
# 20      Oakton High School
# 21      McLean High School
# 22      McLean High School
# 23      McLean High School
# 24      McLean High School
# 25      McLean High School
# 26      McLean High School
# 27      McLean High School
# 28      McLean High School
# 29      McLean High School
# ..                     ...
# 114                    NaN
# 115                    NaN
# 116                    NaN
# 117                    NaN
# 118                    NaN
# 119                    NaN
# 120                    NaN
# 121                    NaN
# 122                    NaN
# 123                    NaN
# 124                    NaN
# 125                    NaN
# 126                    NaN
# 127                    NaN
# 128                    NaN
# 129                    NaN
# 130                    NaN
# 131                    NaN
# 132                    NaN
# 133                    NaN
# 134                    NaN
# 135     Oakton High School
# 136     Oakton High School
# 137     Oakton High School
# 138     Oakton High School
# 139     Oakton High School
# 140     Oakton High School
# 141     Oakton High School
# 142     Oakton High School
# 143     Oakton High School
#
# [144 rows x 20 columns]

# %%
# pre-setting:

# NaN in HOA & days on market to -1
result['HOA/MONTH'] = result['HOA/MONTH'].fillna(-1)
result['DAYS ON MARKET'] = result['DAYS ON MARKET'].fillna(-1)
# year build to 9999
result['YEAR BUILT'] = result['YEAR BUILT'].fillna(9999)

#### DO FILTERING
# 1. filter TH or SFH
# 2. filter on market > 60 days
# 3. HOA < 250

# 1. Vacant Land
# 2. Single Family Residential
# 3. Condo/Co-op
# 4. Townhouse
house_type_to_keep = ["Single Family Residential", "Townhouse"]

rslt_df = result.loc[result['PROPERTY TYPE'].isin(house_type_to_keep) & 
                    (result['HOA/MONTH'] < 200) & # HOA < 200
                    (result['DAYS ON MARKET'] < 40) & # days on market < 40
                    (result['YEAR BUILT'] > 1980)] # year build > 2000


rslt_df
# Out:
#                  SALE TYPE              PROPERTY TYPE                ADDRESS  \
# 12   New Construction Plan                  Townhouse              Garrett I
# 14             MLS Listing  Single Family Residential  13989 Cabells Mill Dr
# 15             MLS Listing  Single Family Residential    13531 Knotty Log Ct
# 18             MLS Listing                  Townhouse          2882 Kelly Sq
# 47             MLS Listing  Single Family Residential     21835 Inglewood Ct
# 49             MLS Listing                  Townhouse     21814 Goldhawk Ter
# 51   New Construction Plan                  Townhouse                Aldwych
# 52   New Construction Plan                  Townhouse                Mayfair
# 59             MLS Listing                  Townhouse   8852 Mansion View Ct
# 121  New Construction Plan                  Townhouse                  Hayes
# 122  New Construction Plan                  Townhouse          Strauss Attic
# 123  New Construction Plan                  Townhouse      Hepburn with Loft
# 124  New Construction Plan  Single Family Residential                  Haven
# 125  New Construction Plan                  Townhouse                Strauss
# 126  New Construction Plan  Single Family Residential                 Parker
# 127  New Construction Plan                  Townhouse                Hepburn
# 128  New Construction Plan                  Townhouse                Picasso
#
#             CITY  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 12       Fairfax               22033  854990   3.0    3.0       2224.0
# 14   Centreville               20120  669900   4.0    2.5       1782.0
# 15     Chantilly               20151  799900   4.0    2.5       2654.0
# 18        Vienna               22181  699950   3.0    3.5       1584.0
# 47    Broadlands               20148  880000   4.0    3.5       4022.0
# 49    Broadlands               20148  792256   3.0    3.0       2708.0
# 51    Broadlands               20148  785490   3.0    2.5       2708.0
# 52    Broadlands               20148  777865   3.0    2.5       2708.0
# 59        Vienna               22182  669900   3.0    2.5       2052.0
# 121      Herndon               20171  734990   3.0    2.5       2446.0
# 122      Herndon               20171  794990   4.0    3.5       2377.0
# 123      Herndon               20171  644990   3.0    4.0       1940.0
# 124      Herndon               20171  784990   5.0    4.0       2736.0
# 125      Herndon               20171  744990   4.0    3.5       2022.0
# 126      Herndon               20171  754990   5.0    4.0       2506.0
# 127      Herndon               20171  614990   3.0    3.0       1548.0
# 128      Herndon               20171  604990   3.0    2.5       2481.0
#
#      LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  STATUS  \
# 12        NaN      9999.0            -1.0          384.0       -1.0  Active
# 14    15367.0      1982.0             1.0          376.0       13.0  Active
# 15    11812.0      1986.0             2.0          301.0       43.0  Active
# 18     1650.0      1982.0             2.0          442.0      110.0  Active
# 47     9583.0      2003.0             2.0          219.0      164.0  Active
# 49        NaN      2022.0             6.0          293.0      138.0  Active
# 51        NaN      9999.0            -1.0          290.0       -1.0  Active
# 52        NaN      9999.0            -1.0          287.0       -1.0  Active
# 59      873.0      1999.0             4.0          326.0      191.0  Active
# 121       NaN      9999.0            -1.0          300.0       -1.0  Active
# 122       NaN      9999.0            -1.0          334.0       -1.0  Active
# 123       NaN      9999.0            -1.0          332.0       -1.0  Active
# 124       NaN      9999.0            -1.0          287.0       -1.0  Active
# 125       NaN      9999.0            -1.0          368.0       -1.0  Active
# 126       NaN      9999.0            -1.0          301.0       -1.0  Active
# 127       NaN      9999.0            -1.0          397.0       -1.0  Active
# 128       NaN      9999.0            -1.0          244.0       -1.0  Active
#
#     URL (SEE https://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)  \
# 12   https://www.redfin.com/VA/Fairfax/The-Towns-at...
# 14   https://www.redfin.com/VA/Centreville/13989-Ca...
# 15   https://www.redfin.com/VA/Chantilly/13531-Knot...
# 18   https://www.redfin.com/VA/Vienna/2882-Kelly-Sq...
# 47   https://www.redfin.com/VA/Broadlands/21835-Ing...
# 49   https://www.redfin.com/VA/Broadlands/21814-Gol...
# 51   https://www.redfin.com/VA/Ashburn/Demott-Silve...
# 52   https://www.redfin.com/VA/Ashburn/Demott-Silve...
# 59   https://www.redfin.com/VA/Vienna/8852-Mansion-...
# 121  https://www.redfin.com/VA/Herndon/Woodland-Par...
# 122  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
# 123  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
# 124  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
# 125  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
# 126  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
# 127  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
# 128  https://www.redfin.com/VA/Herndon/Foster-s-Gle...
#
#           Elementary School      MLS Number              Middle School  \
# 12   Navy Elementary School  Plan-181848292     Franklin Middle School
# 14   Poplar Tree Elementary     VAFX2041912           Rocky Run Middle
# 15   Poplar Tree Elementary     VAFX2041554           Rocky Run Middle
# 18   Mosby Woods Elementary     VAFX2040210                        NaN
# 47      Mill Run Elementary     VALO2015278  Eagle Ridge Middle School
# 49      Mill Run Elementary     VALO2015646  Eagle Ridge Middle School
# 51      Mill Run Elementary  Plan-181907104  Eagle Ridge Middle School
# 52      Mill Run Elementary  Plan-181907103  Eagle Ridge Middle School
# 59     Westbriar Elementary     VAFX2040576                        NaN
# 121                     NaN  Plan-181720282       Carson Middle School
# 122                     NaN  Plan-181939532       Carson Middle School
# 123                     NaN  Plan-181885689       Carson Middle School
# 124                     NaN  Plan-181910609       Carson Middle School
# 125                     NaN  Plan-181885688       Carson Middle School
# 126                     NaN  Plan-181910608       Carson Middle School
# 127                     NaN  Plan-181885687       Carson Middle School
# 128                     NaN  Plan-181916749       Carson Middle School
#
#                  High School
# 12        Oakton High School
# 14     Chantilly High School
# 15     Chantilly High School
# 18        Oakton High School
# 47   Briar Woods High School
# 49   Briar Woods High School
# 51   Briar Woods High School
# 52   Briar Woods High School
# 59                       NaN
# 121                      NaN
# 122                      NaN
# 123                      NaN
# 124                      NaN
# 125                      NaN
# 126                      NaN
# 127                      NaN
# 128                      NaN

# %%
# sort result by year and price ASC
final = rslt_df.sort_values(by=['PRICE','YEAR BUILT'], ascending=True)
# write into result csv
final.to_csv(today_path + "/home_suggestion.csv", index=False)
